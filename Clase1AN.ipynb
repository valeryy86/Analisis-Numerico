# %%
print("hola")
# Out:
# hola

# %%
# %cd /content/drive/MyDrive/Analisis_Numerico/Analisis-Numerico
# Out:
# /content/drive/MyDrive/Analisis_Numerico/Analisis-Numerico

# %%
# %cd Analisis-Numerico
# Out:
# /content/drive/MyDrive/Analisis_Numerico/Analisis-Numerico/Analisis-Numerico

# %%
# !ls

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Analisis_Numerico/Analisis-Numerico/Analisis-Numerico

# %%
# !ls

# %%
# !git status
# Out:
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !ls
